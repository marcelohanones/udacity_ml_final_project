# %% [markdown]
# # Load Libraries / Data

# %%
# %run ../modules/library_to_import.ipynb

# %%
# %run ../modules/Class_imdb.ipynb
# %run ../modules/transformers_imdb.ipynb

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# sns.despine()
sns.set()
# sns.set(style='white', context='notebook', palette='deep')
# sns.set(style='white', palette='deep')
sns.despine()

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)  
warnings.filterwarnings("ignore", category=UserWarning)  

np.set_printoptions(precision=2)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [raw]
# evaluations_all -  it is a dictionary where all the information regarding models performance scores gets recorded. It`s the 'cloud'.
#
# By acessing the 'cloud' the Class Super_Analtica will work in groups.
# Analytica_bolada is lower level.

# %% [markdown]
# ## Data

# %%
df = pd.read_csv('../../data/movie_data.csv')
df.head(5)
# Out:
#                                               review  sentiment
# 0  It's hard to put your finger on this one. Basi...          1
# 1  I mean, nothing happens, 5 dumb kids go to Okl...          0
# 2  "Så som in himmelen" was probably one of the 3...          1
# 3  This noir may not be the best remembered film ...          1
# 4  I'll be honest with yall, I was a junior in hi...          1

# %%
X = df['review'].values
y = df['sentiment'].values

# %%
# %load ./params_imdb.ipynb

# %%
df.head()
df.info()
# Out:
#                                               review  sentiment
# 0  It's hard to put your finger on this one. Basi...          1
# 1  I mean, nothing happens, 5 dumb kids go to Okl...          0
# 2  "Så som in himmelen" was probably one of the 3...          1
# 3  This noir may not be the best remembered film ...          1
# 4  I'll be honest with yall, I was a junior in hi...          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
# review       50000 non-null object
# sentiment    50000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 781.3+ KB

# %%
df.sentiment.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: sentiment, dtype: float64

# %% [raw]
# feature union is for applying different vectorizers for different columns

# %% [markdown]
# # X  y

# %%
random_state = 42

# # DATAFRAMES USED ONLY WHEN NEED MORE THAN 1 COLUMN
# WORKS with sklearn-pandas to drive dataframes in sklearn or column extractor e To_Matrix

# X_train = df.loc[:100, ['review']].reset_index(drop=True)
# y_train = df.loc[:100, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[49900:, ['review']].reset_index(drop=True)
# y_test = df.loc[49900:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:200, ['review']].reset_index(drop=True)
# y_train = df.loc[:200, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[49800:, ['review']].reset_index(drop=True)
# y_test = df.loc[49800:, ['sentiment']].reset_index(drop=True)

# AQUIIIIIII
X_train = df.loc[:8000, ['review']].reset_index(drop=True)
y_train = df.loc[:8000, ['sentiment']].reset_index(drop=True)
X_test = df.loc[46000:, ['review']].reset_index(drop=True)
y_test = df.loc[46000:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:10000, ['review']].reset_index(drop=True)
# y_train = df.loc[:10000, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[40000:, ['review']].reset_index(drop=True)
# y_test = df.loc[40000:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:20000, ['review']].reset_index(drop=True)
# y_train = df.loc[:20000, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[45000:, ['review']].reset_index(drop=True)
# y_test = df.loc[45000:, ['sentiment']].reset_index(drop=True)

kfold = StratifiedKFold(n_splits=5, shuffle=False, random_state=random_state)
# kfold = 5
# kfold = 4

# %%
X_train
# Out:
#                                                  review
# 0     It's hard to put your finger on this one. Basi...
# 1     I mean, nothing happens, 5 dumb kids go to Okl...
# 2     "Så som in himmelen" was probably one of the 3...
# 3     This noir may not be the best remembered film ...
# 4     I'll be honest with yall, I was a junior in hi...
# 5     Damon Runyon's world of Times Square, in New Y...
# 6     After a group of young friends experience car ...
# 7     What makes for Best Picture material? The Osca...
# 8     I found this film extremely disturbing. Treadw...
# 9     This DVD set is the complete widescreen 15-epi...
# 10    Kevin Kline and Meg Ryan are among that class ...
# 11    Well...there were some great, creamy-smooth fa...
# 12    If I had not read Pat Barker's 'Union Street' ...
# 13    This movie is fun to watch. If you liked "Dave...
# 14    A charming, funny film that gets a solid grade...
# 15    The movie is about a day in the life of a woma...
# ...

# %%
X_test
# Out:
#                                                  review
# 0     Rich, alcoholic Robert Stack falls in love wit...
# 1     Don't understand how these animated movies kee...
# 2     Wings Hauser and son, Cole Hauser team up to m...
# 3     I always hated this retarded show .I liked the...
# 4     The movie never becomes intolerable to watch. ...
# 5     The SF premise isn't unique (although it prett...
# 6     Pink Flamingos is a movie no word can explain....
# 7     This program was quite interesting. The way th...
# 8     Sometimes a movie is so bad it's kind of good....
# 9     I saw Beyond Rangoon about 20 times, it was TH...
# 10    Get ready for it: This is one of my favourite ...
# 11    I thought this was a great idea but, boy, was ...
# 12    This is a hard show to watch. It's not somethi...
# 13    Had she not been married to the producer, Jenn...
# 14    Very strange but occasionally elegant exploita...
# 15    The sword fighting was out of this world, the ...
# ...

# %%
y_train
# Out:
#       sentiment
# 0             1
# 1             0
# 2             1
# 3             1
# 4             1
# 5             1
# 6             1
# 7             1
# 8             0
# 9             1
# 10            0
# 11            0
# 12            0
# 13            1
# 14            1
# 15            0
# 16            1
# 17            1
# 18            0
# 19            0
# 20            1
# 21            1
# 22            1
# 23            1
# 24            0
# 25            1
# 26            0
# 27            1
# 28            1
# 29            0
# ...         ...
# 7971          1
# 7972          0
# 7973          1
# 7974          1
# 7975          0
# 7976          0
# 7977          0
# 7978          1
# 7979          0
# 7980          0
# 7981          1
# 7982          1
# 7983          1
# 7984          1
# 7985          1
# 7986          1
# 7987          0
# 7988          1
# 7989          1
# 7990          0
# 7991          0
# 7992          0
# 7993          1
# ...

# %%
y_test
# Out:
#       sentiment
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# 5             1
# 6             1
# 7             1
# 8             1
# 9             1
# 10            1
# 11            0
# 12            1
# 13            0
# 14            0
# 15            1
# 16            0
# 17            0
# 18            0
# 19            0
# 20            1
# 21            1
# 22            1
# 23            1
# 24            0
# 25            0
# 26            0
# 27            0
# 28            1
# 29            1
# ...         ...
# 3970          0
# 3971          0
# 3972          0
# 3973          0
# 3974          1
# 3975          0
# 3976          1
# 3977          0
# 3978          1
# 3979          0
# 3980          1
# 3981          1
# 3982          0
# 3983          1
# 3984          1
# 3985          1
# 3986          1
# 3987          1
# 3988          1
# 3989          0
# 3990          0
# 3991          0
# 3992          1
# ...

# %%
X_train.shape
# X_train.info()
type(X_train)
# Out:
# (8001, 1)
# pandas.core.frame.DataFrame

# %%
y_train.shape
# y_train.info()
type(y_train)
# Out:
# (8001, 1)
# pandas.core.frame.DataFrame

# %%
X_test.shape
# X_test.info()
type(X_test)
# Out:
# (4000, 1)
# pandas.core.frame.DataFrame

# %%
y_test.shape
# y_train.info()
type(y_test)
# Out:
# (4000, 1)
# pandas.core.frame.DataFrame

# %% [markdown]
# # Vocabulary

# %%
# %%time
# Defining Vocab
pipe = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('counts', CountVectorizer(max_features=5000, stop_words='english', min_df=3, 
                               tokenizer=tokenizer_porter))
])

train_features_matrix_1 = pipe.fit_transform(X_train)
vocab = pipe.named_steps['counts'].get_feature_names()
# Out:
# CPU times: user 59 s, sys: 502 ms, total: 59.5 s
# Wall time: 1min

# %%
filename = 'vocab_5'

# %%
# saving vocabulary with pickle
# joblib.dump(vocab, '../pkl/'+ filename + '.pkl') 

# loading vocabulary previoulsy pickled
vocab = joblib.load('../pkl/'+ filename + '.pkl') 
len(vocab)
# Out:
# 5000

# %% [markdown]
# # PRE LOADING

# %%
def tokenizer_split(text):
    return [porter.stem(w) for w in text.split(' ')]

def tokenizer_porter(text):
    return [porter.stem(w) for w in text.split(' ') if not w in stop_words ]

tfidf = TfidfVectorizer(strip_accents=None, lowercase=False, preprocessor=None)

# %%
master = Super_Analytica('master')

# %%
stop_words = nltk.corpus.stopwords.words('english')
porter = PorterStemmer()

# %%
# %run ../modules/params_imdb.ipynb

# %%
master.evaluate_CV(pipe_1_1, ['LGR'] , '_16_pipe1_1', pkl_W=True)
# Out:
# LGR_16_pipe1_1   Cross Validation and Pickled Done in  51.0  minutes  /-->acc : 0.5

# %% [markdown]
# # Steven thornton

# %%
clf['SGDC_2'] = SGDClassifier(loss='modified_huber', penalty='elasticnet', n_iter= 75, l1_ratio = 0.0011725603957849658, alpha = 4.8297400463260401e-05  )

# %%
best_params = {
    'kbest__percentile': 58.810014948672134,
    'vec__max_df': 0.77265658163292117,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3),
    'vec__sublinear_tf': True
}

# %%
# variacao do pipe 1
pipe_6 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer()),  
    ('kbest', SelectPercentile(chi2)),
    ('Normalize', Normalizer(copy=False))

])
# Out:
# Pipeline(memory=None,
#      steps=[('col', Col_Extractor(cols=['review'])), ('prep', Preprocessor()), ('to_array', To_array()), ('vec', TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=0.7726565816329212,...     score_func=<function chi2 at 0x1a0c1b2a60>)), ('Normalize', Normalizer(copy=False, norm='l2'))])

# %%
pipe_6.set_params(**best_params)
master.evaluate_CV(pipe_6, ['SGDC_2'])
# pipe_6.fit(X_train, y_train)
# Out:
# SGDC_2   Cross Validation Done in  7.0  minutes  /-->acc : 0.9696434783670375

# %%
# pipe antigao Com Vocab
pipe_7 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', CountVectorizer(vocabulary=vocab)),
    ('tf-idf', TfidfTransformer()),
    ('kbest', SelectPercentile(chi2)),
    ('Normalize', Normalizer(copy=False))
])

best_params7 = {
    'kbest__percentile': 58.810014948672134,
    'vec__max_df': 0.77265658163292117,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3)
}

pipe_7.set_params(**best_params7)
master.evaluate_CV(pipe_7, ['SGDC_2']);
# Out:
# SGDC_2   Cross Validation Done in  2.0  minutes  /-->acc : 0.8917919597937294

# %%
# antigao. retirando o VOCAB e volta pra 0.96
pipe_8 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', CountVectorizer()),
    ('tf-idf', TfidfTransformer()),
    ('kbest', SelectPercentile(chi2)),
    ('Normalize', Normalizer(copy=False))
])

best_params8 = {
    'kbest__percentile': 58.810014948672134,
    'vec__max_df': 0.77265658163292117,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3)
}

pipe_8.set_params(**best_params8)
master.evaluate_CV(pipe_8, ['SGDC_2']);
# Out:
# SGDC_2   Cross Validation Done in  6.0  minutes  /-->acc : 0.9687379107353647

# %%
# antigao. retirando o VOCAB e volta pra 0.96
# Igual ao de cima , so REtirando normalizer pra ver se o normalizer faz diferenca
pipe_8 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', CountVectorizer()),
    ('tf-idf', TfidfTransformer()),
    ('kbest', SelectPercentile(chi2))
])

best_params8 = {
    'kbest__percentile': 58.810014948672134,
    'vec__max_df': 0.77265658163292117,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3)
}

pipe_8.set_params(**best_params8)
master.evaluate_CV(pipe_8, ['SGDC_2']);
# Out:
# SGDC_2   Cross Validation Done in  7.0  minutes  /-->acc : 0.9686651063722598

# %%
# retirando o VOCAB e volta pra 0.96
# Substituindo chi por Truncated SCD  NAO RODA MEMORY INTENSICE
pipe_9 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', CountVectorizer()),
    ('tf-idf', TfidfTransformer()),
    ('TruncatedSVD', TruncatedSVD(n_components=1000)),
    ('Normalize', Normalizer(copy=False))
])

# %%
# retirando o VOCAB e volta pra 0.96
# tentando dicionario maior
pipe_9 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', CountVectorizer(max_features=10000)),
    ('tf-idf', TfidfTransformer()),
    ('TruncatedSVD', TruncatedSVD(n_components=4000)),
    ('Normalize', Normalizer(copy=False))
])
best_params9 = {
#     'kbest__percentile': 58.810014948672134,
    'vec__max_df': 0.77265658163292117,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3)
}

pipe_9.set_params(**best_params9)
master.evaluate_CV(pipe_9, ['SGDC_2']);
# Out:
# SGDC_2   Cross Validation Done in  44.0  minutes  /-->acc : 0.954826493669759

# %% [raw]
# CONCLUSAO: TRUNCATEDSVD é pesado e deixa o processo bem mais lento.

# %%
# achar diferentes metodos de dim reduction.
# testar chi2, Mutual information

# %%
# HP

# %%
# HP# comKbest no lugar de  Truncated,nao funcionou com n_jobs=-1
pipe_6 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer()),  
    ('kbest', SelectPercentile(chi2))
])

param['SGDC'] = {'vec__ngram_range': hp.choice('vec__ngram_range', [(1, 1), (1, 2), (1, 3)]),
                 'vec__min_df': 1+hp.randint('vec__min_df', 3),
                 'vec__max_df': hp.uniform('vec__max_df', 0.7, 1.0),
                 'vec__sublinear_tf': hp.choice('vec__sublinear_tf', [True, False]),
                 'kbest__percentile': hp.uniform('kbest__percentile', 50, 100),
                 'SGDC__l1_ratio': hp.uniform('clf__l1_ratio', 0.0, 1.0),
                 'SGDC__alpha': hp.loguniform('clf__alpha', -9*np.log(10), -4*np.log(10)),
                 'SGDC__n_iter': 20 + 5*hp.randint('clf__n_iter', 12)}

# %%
md_SGDC = Analytica_Bolada('SGDC', param['SGDC'], 'SGDC')
md_SGDC.evaluate_HP3(pipe_6, pkl_W=False)

# %%
xgboost={
            'max_depth': hp.choice('x_max_depth',[2,3,4]),
            'min_child_weight':hp.choice('x_min_child_weight',np.round(np.arange(0.0,0.2,0.01),5)),
            'learning_rate':hp.choice('x_learning_rate',np.round(np.arange(0.005,0.3,0.01),5)),
            'subsample':hp.choice('x_subsample',np.round(np.arange(0.1,1.0,0.05),5)),
            'colsample_bylevel':hp.choice('x_colsample_bylevel',np.round(np.arange(0.1,1.0,0.05),5)),
            'colsample_bytree':hp.choice('x_colsample_bytree',np.round(np.arange(0.1,1.0,0.05),5)),
            'n_estimators':hp.choice('x_n_estimators',np.arange(25,100,5))
            }
param['XGB'] = xgboost

# %%
md_XGB = Analytica_Bolada('XGB', param['XGB'], 'XGB')
md_XGB.evaluate_HP3(pipe_6)

# %%
param['xgboost']
# Out:
# {'max_depth': <hyperopt.pyll.base.Apply at 0x1a18e87b38>,
#  'min_child_weight': <hyperopt.pyll.base.Apply at 0x1a18e87d30>,
#  'learning_rate': <hyperopt.pyll.base.Apply at 0x1a18e852e8>,
#  'subsample': <hyperopt.pyll.base.Apply at 0x1a18e85a90>,
#  'colsample_bylevel': <hyperopt.pyll.base.Apply at 0x1a18e85f98>,
#  'colsample_bytree': <hyperopt.pyll.base.Apply at 0x1a18e864e0>,
#  'n_estimators': <hyperopt.pyll.base.Apply at 0x1a18e869e8>}
