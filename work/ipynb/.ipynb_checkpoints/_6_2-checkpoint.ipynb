# %% [markdown]
# # Load Data / Libs

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %run ../modules/library_to_import.ipynb

# %%
# %run ../modules/Class_imdb.ipynb
# %run ../modules/transformers_imdb.ipynb

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)  
warnings.filterwarnings("ignore", category=UserWarning)  

# np.set_printoptions(precision=2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# sns.despine()
sns.set()
# sns.set(style='white', context='notebook', palette='deep')
# sns.set(style='white', palette='deep')
sns.despine()

# %% [markdown]
# # Data

# %%
# basepath = './aclImdb'
basepath = '../data/aclImdb'

labels = {'pos': 1, 'neg': 0}
pbar = pyprind.ProgBar(50000)
df = pd.DataFrame()
for s in ('test', 'train'):
    for l in ('pos', 'neg'):
        path = os.path.join(basepath, s, l)
        for file in os.listdir(path):
            # For python2, use 'io.open', for Python3, just us 'open' 
            with io.open(os.path.join(path, file), 'r', encoding='utf-8') as infile:
                txt = infile.read()
            df = df.append([[txt, labels[l]]], ignore_index=True)
            pbar.update()
df.columns = ['review', 'sentiment']

# %%
X = df.loc[:,:].values
X.shape

# %%
# Saving to file
np.random.seed(0)
df = df.reindex(np.random.permutation(df.index))
df.to_csv('../data/movie_data.csv', index=False, encoding='utf-8')

# %%
df = pd.read_csv('../../data/movie_data.csv')
df.head(5)
# Out:
#                                               review  sentiment
# 0  It's hard to put your finger on this one. Basi...          1
# 1  I mean, nothing happens, 5 dumb kids go to Okl...          0
# 2  "Så som in himmelen" was probably one of the 3...          1
# 3  This noir may not be the best remembered film ...          1
# 4  I'll be honest with yall, I was a junior in hi...          1

# %%
X = df['review'].values
y = df['sentiment'].values

# %%
# %load ./params_imdb.ipynb

# %%
# %run ../modules/Class_imdb.ipynb
# %run ../modules/transformers_imdb.ipynb

# %%
df.head()
df.info()
# Out:
#                                               review  sentiment
# 0  It's hard to put your finger on this one. Basi...          1
# 1  I mean, nothing happens, 5 dumb kids go to Okl...          0
# 2  "Så som in himmelen" was probably one of the 3...          1
# 3  This noir may not be the best remembered film ...          1
# 4  I'll be honest with yall, I was a junior in hi...          1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
# review       50000 non-null object
# sentiment    50000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 781.3+ KB

# %%
df.sentiment.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: sentiment, dtype: float64

# %% [raw]
# feature union is for applying different vectorizers for different columns

# %% [markdown]
# # X  y

# %%
random_state = 42

# # DATAFRAMES USED ONLY WHEN NEED MORE THAN 1 COLUMN
# WORKS with sklearn-pandas to drive dataframes in sklearn or column extractor e To_Matrix

# X_train = df.loc[:100, ['review']].reset_index(drop=True)
# y_train = df.loc[:100, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[49900:, ['review']].reset_index(drop=True)
# y_test = df.loc[49900:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:2000, ['review']].reset_index(drop=True)
# y_train = df.loc[:2000, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[48000:, ['review']].reset_index(drop=True)
# y_test = df.loc[48000:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:5000, ['review']].reset_index(drop=True)
# y_train = df.loc[:5000, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[45000:, ['review']].reset_index(drop=True)
# y_test = df.loc[45000:, ['sentiment']].reset_index(drop=True)

X_train = df.loc[:12000, ['review']].reset_index(drop=True)
y_train = df.loc[:12000, ['sentiment']].reset_index(drop=True)
X_test = df.loc[46000:, ['review']].reset_index(drop=True)
y_test = df.loc[46000:, ['sentiment']].reset_index(drop=True)

# X_train = df.loc[:25000, ['review']].reset_index(drop=True)
# y_train = df.loc[:25000, ['sentiment']].reset_index(drop=True)
# X_test = df.loc[25000:, ['review']].reset_index(drop=True)
# y_test = df.loc[25000:, ['sentiment']].reset_index(drop=True)

kfold = StratifiedKFold(n_splits=5, shuffle=False, random_state=random_state)
# kfold = 5
# kfold = 4

# %%
# X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.5, stratify=y)

# %%
X_train
# Out:
#                                                   review
# 0      It's hard to put your finger on this one. Basi...
# 1      I mean, nothing happens, 5 dumb kids go to Okl...
# 2      "Så som in himmelen" was probably one of the 3...
# 3      This noir may not be the best remembered film ...
# 4      I'll be honest with yall, I was a junior in hi...
# 5      Damon Runyon's world of Times Square, in New Y...
# 6      After a group of young friends experience car ...
# 7      What makes for Best Picture material? The Osca...
# 8      I found this film extremely disturbing. Treadw...
# 9      This DVD set is the complete widescreen 15-epi...
# 10     Kevin Kline and Meg Ryan are among that class ...
# 11     Well...there were some great, creamy-smooth fa...
# 12     If I had not read Pat Barker's 'Union Street' ...
# 13     This movie is fun to watch. If you liked "Dave...
# 14     A charming, funny film that gets a solid grade...
# ...

# %%
X_test
# Out:
#                                                  review
# 0     Rich, alcoholic Robert Stack falls in love wit...
# 1     Don't understand how these animated movies kee...
# 2     Wings Hauser and son, Cole Hauser team up to m...
# 3     I always hated this retarded show .I liked the...
# 4     The movie never becomes intolerable to watch. ...
# 5     The SF premise isn't unique (although it prett...
# 6     Pink Flamingos is a movie no word can explain....
# 7     This program was quite interesting. The way th...
# 8     Sometimes a movie is so bad it's kind of good....
# 9     I saw Beyond Rangoon about 20 times, it was TH...
# 10    Get ready for it: This is one of my favourite ...
# 11    I thought this was a great idea but, boy, was ...
# 12    This is a hard show to watch. It's not somethi...
# 13    Had she not been married to the producer, Jenn...
# 14    Very strange but occasionally elegant exploita...
# 15    The sword fighting was out of this world, the ...
# ...

# %%
y_train
# Out:
#        sentiment
# 0              1
# 1              0
# 2              1
# 3              1
# 4              1
# 5              1
# 6              1
# 7              1
# 8              0
# 9              1
# 10             0
# 11             0
# 12             0
# 13             1
# 14             1
# 15             0
# 16             1
# 17             1
# 18             0
# 19             0
# 20             1
# 21             1
# 22             1
# 23             1
# 24             0
# 25             1
# 26             0
# 27             1
# 28             1
# 29             0
# ...          ...
# 11971          0
# 11972          0
# 11973          0
# 11974          0
# 11975          1
# 11976          0
# 11977          0
# 11978          0
# 11979          0
# 11980          1
# 11981          1
# 11982          0
# 11983          1
# 11984          0
# 11985          0
# 11986          0
# 11987          1
# 11988          1
# 11989          0
# 11990          0
# ...

# %%
y_test
# Out:
#       sentiment
# 0             1
# 1             0
# 2             0
# 3             0
# 4             0
# 5             1
# 6             1
# 7             1
# 8             1
# 9             1
# 10            1
# 11            0
# 12            1
# 13            0
# 14            0
# 15            1
# 16            0
# 17            0
# 18            0
# 19            0
# 20            1
# 21            1
# 22            1
# 23            1
# 24            0
# 25            0
# 26            0
# 27            0
# 28            1
# 29            1
# ...         ...
# 3970          0
# 3971          0
# 3972          0
# 3973          0
# 3974          1
# 3975          0
# 3976          1
# 3977          0
# 3978          1
# 3979          0
# 3980          1
# 3981          1
# 3982          0
# 3983          1
# 3984          1
# 3985          1
# 3986          1
# 3987          1
# 3988          1
# 3989          0
# 3990          0
# 3991          0
# 3992          1
# ...

# %%
X_train.shape
# X_train.info()
type(X_train)
# Out:
# (12001, 1)
# pandas.core.frame.DataFrame

# %%
y_train.shape
# y_train.info()
type(y_train)
# Out:
# (12001, 1)
# pandas.core.frame.DataFrame

# %%
X_test.shape
# X_test.info()
type(X_test)
# Out:
# (4000, 1)
# pandas.core.frame.DataFrame

# %%
y_test.shape
# y_train.info()
type(y_test)
# Out:
# (4000, 1)
# pandas.core.frame.DataFrame

# %% [markdown]
# # PRE LOADING

# %% [markdown]
# ## Functions, instances

# %%
def tokenizer_split(text):
    return [porter.stem(w) for w in text.split(' ')]

def tokenizer_porter(text):
    return [porter.stem(w) for w in text.split(' ') if not w in stop_words ]

tfidf = TfidfVectorizer(strip_accents=None, lowercase=False, preprocessor=None)

# %%
master = Super_Analytica('master')

# %%
stop_words = nltk.corpus.stopwords.words('english')
porter = PorterStemmer()

# %%
# %run ../modules/params_imdb.ipynb

# %% [markdown]
# ## Vocab

# %%
# filename = 'vocab_3'

# %%
# loading vocabulary
# vocab = joblib.load('../pkl/'+ filename + '.pkl') 
# len(vocab)

# %% [markdown]
# # Load Pickle _1

# %% [raw]
#  - work in high level - Super Analytica

# %%
master.get_members_evaluations_all()
# Out:
# dict_keys([])

# %% [raw]
# estes sao todos os modelos que foram treinados no passo anterior.
# 'DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2', 'DT_pp3', 'ADA_pp3', 'RF_pp3',
#  'XT_pp3', 'KNN_pp3', 'LinearSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4',
#  'LinearSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5'

# %% [raw]
# Criaremos agregadores para facilitar a analise por agrupamentos que facam
# sentido para a analise.

# %%
#Agrupando por pipe
md_pp2 = ['DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2']
md_pp3 = ['DT_pp3', 'ADA_pp3', 'RF_pp3', 'XT_pp3', 'KNN_pp3'] 
md_pp4 = ['LinearSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4']
md_pp5 = ['LinearSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5']

# %%
# AGrupando por Parametricos e Nao Parametricos
md_Par = md_pp4 + md_pp5
md_NPar = md_pp2 + md_pp3

# %%
md_all = [md_Par + md_NPar]  # md_all must be a list of lists

# %%
md_all
# Out:
# [['LinearSVC_pp4',
#   'LGR_pp4',
#   'RDG_pp4',
#   'NB_pp4',
#   'SGDC_pp4',
#   'LinearSVC_pp5',
#   'LGR_pp5',
#   'RDG_pp5',
#   'NB_pp5',
#   'SGDC_pp5',
#   'DT_pp2',
#   'ADA_pp2',
#   'RF_pp2',
#   'XT_pp2',
#   'KNN_pp2',
#   'DT_pp3',
#   'ADA_pp3',
#   'RF_pp3',
#   'XT_pp3',
#   'KNN_pp3']]

# %%
for L in md_all:
    for name in L:
        master.pkl_R(name)
# Out:
# Done. LinearSVC_pp4 evaluation pickled from pisk
# Done. LGR_pp4 evaluation pickled from pisk
# Done. RDG_pp4 evaluation pickled from pisk
# Done. NB_pp4 evaluation pickled from pisk
# Done. SGDC_pp4 evaluation pickled from pisk
# Done. LinearSVC_pp5 evaluation pickled from pisk
# Done. LGR_pp5 evaluation pickled from pisk
# Done. RDG_pp5 evaluation pickled from pisk
# Done. NB_pp5 evaluation pickled from pisk
# Done. SGDC_pp5 evaluation pickled from pisk
# Done. DT_pp2 evaluation pickled from pisk
# Done. ADA_pp2 evaluation pickled from pisk
# Done. RF_pp2 evaluation pickled from pisk
# Done. XT_pp2 evaluation pickled from pisk
# Done. KNN_pp2 evaluation pickled from pisk
# Done. DT_pp3 evaluation pickled from pisk
# Done. ADA_pp3 evaluation pickled from pisk
# Done. RF_pp3 evaluation pickled from pisk
# Done. XT_pp3 evaluation pickled from pisk
# Done. KNN_pp3 evaluation pickled from pisk

# %%
master.get_members_evaluations_all()
# Out:
# dict_keys(['LinearSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4', 'LinearSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5', 'DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2', 'DT_pp3', 'ADA_pp3', 'RF_pp3', 'XT_pp3', 'KNN_pp3'])

# %% [markdown]
# # Scores x Tempo

# %%
# analisando os scores e os tempos

# %%
master.plot_ranking()

# %%
master.plot_ranking(var='minutes')

# %% [raw]
# Conclusao: No geral os algos parametricos performaram melhor tanto em score como em tempo.

# %% [markdown]
# ____________________

# %%
master.plot_learning_curve(chosen=md_Par)
# Out:
# opening the image LGR_pp4
# opening the image LGR_pp5
# opening the image LinearSVC_pp4
# opening the image LinearSVC_pp5
# opening the image NB_pp4
# opening the image NB_pp5
# opening the image RDG_pp4
# opening the image RDG_pp5
# opening the image SGDC_pp4
# opening the image SGDC_pp5

# %%
master.plot_learning_curve(chosen=md_NPar)
# Out:
# opening the image ADA_pp2
# opening the image ADA_pp3
# opening the image DT_pp2
# opening the image DT_pp3
# opening the image KNN_pp2
# opening the image KNN_pp3
# opening the image RF_pp2
# opening the image RF_pp3
# opening the image XT_pp2
# opening the image XT_pp3

# %% [raw]
# Conclusao: Ambos grupos apresentaram sinais de overfitting com  score de treinamento em torno de 1.
# Porem, os algo Parametricos mostraram me lhor poder de generalizacao com os scores de teste convergindo com o score de treino. Os algo nao parametricos se mostraram em completo estado de overfitting, logo sem poder algum de generalizacao.

# %% [markdown]
# ____________________

# %% [markdown]
# #  O Pipeline 2 é melhor do que o 3 ?

# %%
master.plot_ranking(chosen=md_pp2)

# %%
master.plot_ranking(chosen=md_pp3)

# %% [raw]
# Conclusao: Nao ha diferenca entre os pipeline 2 e o pipeline 3.

# %%
 master.plot_ranking(chosen=md_pp4)

# %%
master.plot_ranking(chosen=md_pp5)

# %% [raw]
# Conclusao: Nao ha diferenca entre os pipeline 4 e o pipeline 5.

# %% [raw]
# Seguiremos usando os Pipelines 2 np e 4 P

# %% [markdown]
# ___________________________

# %% [markdown]
# # atacando VAriance nos algo nao parametricos

# %% [raw]
# Visto que cadaa grupo de algoritmos tem problemas diferentes. Vamos atacar os nao-parametricos com um pipeline
# que torne o dataset mais conciso,com menos features, porem mais complexo. Tecnicas de reducao de dimensionalidade podems er uteis aqui. Seguem alguns testes:

# %%
NonP_algos = clf_T + ['KNN']
NonP_algos
# Out:
# ['DT', 'ADA', 'RF', 'XT', 'KNN']

# %%
warnings.filterwarnings("ignore", category=DataConversionWarning)

# %% [markdown]
# ## Pipe 6

# %%
# max features instead of dimensionality reduction for non parametric

pipe_6 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=5000, stop_words='english'))
])

master.evaluate_CV(pipe_6, NonP_algos, '_pp6', pkl_W=True)
# Out:
# DT_pp6   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.7036647110592356
#
# ADA_pp6   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.7049848995636665
#
# RF_pp6   Cross Validation and Pickled Done in  0.0  minutes  /-->acc : 0.8544381280487755
#
# XT_pp6   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.8665750658976009
#
# KNN_pp6   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.7694416697871242

# %%
# agrupando os modelos processados pelo pipe 6 
md_pp6 = ['DT_pp6', 'ADA_pp6', 'RF_pp6', 'XT_pp6', 'KNN_pp6']
# incuindo os modelos processados pelo pipe 6 na lista geral de modelos.
md_all.append(md_pp6)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp6)

# %% [raw]
# Conclusao: melhora marginal RF, XT, ADA, DT. Melhora significativa: KNN.
# -->  Por enquanto esse é o pipe mais adequado para KNN

# %% [markdown]
# ___________________________

# %% [markdown]
# ## Pipe 7

# %%
pipe_7 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=5000, stop_words='english')),
    ('kbest', SelectPercentile(chi2, percentile=60))
])

# %%
master.evaluate_CV(pipe_7, NonP_algos, '_pp7', pkl_W=True)
# Out:
# DT_pp7   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.7060287102188185
#
# ADA_pp7   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.7089580722543457
#
# RF_pp7   Cross Validation and Pickled Done in  0.0  minutes  /-->acc : 0.8622047021966427
#
# XT_pp7   Cross Validation and Pickled Done in  0.0  minutes  /-->acc : 0.8733988745345773
#
# KNN_pp7   Cross Validation and Pickled Done in  1.0  minutes  /-->acc : 0.6018857800002781

# %%
# agrupando os modelos processados pelo pipe 7
md_pp7 = ['DT_pp7', 'ADA_pp7', 'RF_pp7', 'XT_pp7', 'KNN_pp7']
# incuindo os modelos processados pelo pipe 7 na lista geral de modelos.
md_all.append(md_pp7)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp7)
# Out:
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# posx and posy should be finite values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
# ...

# %% [raw]
# Conclusao: perda marginal KNN. Melhora marginal: XT, ADA, DT, RF

# %% [markdown]
# ______________________________________

# %% [markdown]
# ## Pipe 8

# %%
pipe_8 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=5000, stop_words='english')),
    ('SVD', TruncatedSVD(n_components=500, 
                         algorithm='randomized',
                         n_iter=10, random_state=42))
])
warnings.filterwarnings("ignore", category=DataConversionWarning)
master.evaluate_CV(pipe_8, NonP_algos, '_pp8', pkl_W=True)

# %%
# agrupando os modelos processados pelo pipe 8
md_pp8 = ['DT_pp8', 'ADA_pp8', 'RF_pp8', 'XT_pp8', 'KNN_pp8']
# incuindo os modelos processados pelo pipe 8 na lista geral de modelos.
md_all.append(md_pp8)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp8)

# %%
master.plot_ranking(chosen=md_pp6)

# %% [raw]
# Conclusao: Perda significativa XT, RF. Melhora marginal:ADA, DT. Melhora Significativa: KNN

# %% [markdown]
# __________________________________________

# %% [markdown]
# ## Pipe 9

# %%
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()

    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc)]


pipe_9 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=4000, stop_words='english', tokenizer=LemmaTokenizer())),
    ('kbest', SelectPercentile(chi2))
])

# %%
master.get_members_evaluations_all()
# Out:
# dict_keys(['LinearSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4', 'LinearSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5', 'DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2', 'DT_pp3', 'ADA_pp3', 'RF_pp3', 'XT_pp3', 'KNN_pp3'])

# %%
master.evaluate_CV(pipe_9, NonP_algos, '_pp9', pkl_W=True)
# Out:
# DT_pp9   Cross Validation and Pickled Done in  4.0  minutes  /-->acc : 0.7119938201323732
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-45-536019f12ca5> in <module>()
# ----> 1 master.evaluate_CV(pipe_9, NonP_algos, '_pp9', pkl_W=True)
#
# <ipython-input-9-db88647c0398> in evaluate_CV(self, pipe, chosen, sufix, pkl_W)
#     452 #             print(pipe_copy.named_steps.keys())
#     453             y_pred = cross_val_predict(pipe_copy, X_train, y_train, cv=kfold)
# --> 454             acc = cross_val_score(pipe_copy, X_train, y_train, scoring='roc_auc', cv=kfold).mean()
#     455             end = timer()
#     456             minutes_elapsed = (end - start)//60
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
# ...

# %%
aqui

# %%
# agrupando os modelos processados pelo pipe 7
md_pp9 = ['DT_pp9', 'ADA_pp9', 'RF_pp9', 'XT_pp9', 'KNN_pp9']
# incuindo os modelos processados pelo pipe 9 na lista geral de modelos.
md_all.append(md_pp9)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp9)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp9)

# %% [raw]
# ***Conclusao: Melhora marginal XT, RF, KNN.  Sem alteracao: DT, ADA Melhora
# Pela primeira vez houve melhora em XT, RF, KNN e DT, ADA focaram sem alteracao ao inves de perda.
#
# pp9 = 'Muita perda' : ['' ]
# Pouca Perda
# Pouco Ganho
# Muito Ganho: [' ]

# %%
pp9 = {'Muita Perda': [''],
       'Pouca Perda': [''],
       'Pouco Ganho': ['DT', 'RF', 'XT'],
       'Muito Ganho': ['KNN', 'ADA']}

# %% [markdown]
# ## Pipe 10

# %%
# igual ao 9, so altera o percentile. Percentile fa diferenca ?
pipe_10 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=5000, stop_words='english', tokenizer=LemmaTokenizer())),
    ('kbest', SelectPercentile(chi2, percentile=20))
])

master.evaluate_CV(pipe_10, NonP_algos, '_pp10', pkl_W=True)
# Out:
# DT_pp10   Cross Validation and Pickled Done in  3.0  minutes  /-->acc : 0.7137306052926944
#
# ADA_pp10   Cross Validation and Pickled Done in  4.0  minutes  /-->acc : 0.7141294846458667
#
# RF_pp10   Cross Validation and Pickled Done in  3.0  minutes  /-->acc : 0.859721031673572
#
# XT_pp10   Cross Validation and Pickled Done in  3.0  minutes  /-->acc : 0.8740822430978057
#
# KNN_pp10   Cross Validation and Pickled Done in  4.0  minutes  /-->acc : 0.6396226827291093

# %%
# agrupando os modelos processados pelo pipe 10
md_pp10 = ['DT_pp10', 'ADA_pp10', 'RF_pp10', 'XT_pp10', 'KNN_pp10']
# incuindo os modelos processados pelo pipe 10 na lista geral de modelos.
md_all.append(md_pp10)

# %%
master.plot_ranking(chosen=md_pp2 + md_pp10)

# %% [raw]
# percentil 20 Conclusao: Ganho Marginal: DT, ADA, RF,XT   Perda Marginal: KNN    -->  percentil deve ser menor do que 60.

# %%
pp10 = {'Muita Perda': [''],
       'Pouca Perda': ['KNN'],
       'Pouco Ganho': ['DT', 'ADA', 'RF', 'XT'],
       'Muito Ganho': ['']}

# %% [markdown]
# ## Analisando modelo a modelo

# %%
find_models('ADA')

# %%
master.plot_ranking( find_models('XT'))

# %%
master.plot_ranking( find_models('ADA'))

# %%
master.plot_ranking( find_models('DT'))

# %%
master.plot_ranking( find_models('RF'))

# %%
master.plot_ranking(find_models('KNN'))

# %%
Conclusao: pp_6 --> KNN.    pp_9 --> Trees

# %% [markdown]
# ## Pipe 11 Melhor KNN

# %%
Entendendo que o pipe_6 deu ao KNN seu melhor score, vamos aprofundar para tetar melhorar os scores.

# %%
pipe_11 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(max_features=20000, stop_words='english'))
])
best_params = {
    'vec__max_df': 0.9,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3),
    'vec__sublinear_tf': True
}
pipe_11.set_params(**best_params)

master.evaluate_CV(pipe_11, ['KNN'], '_pp11', pkl_W=True)
master.plot_ranking(find_models('KNN'));

# %%
# agrupando os modelos processados pelo pipe 10
md_pp11 = ['KNN_pp11']
# incuindo os modelos processados pelo pipe 10 na lista geral de modelos.
md_all.append(md_pp11)

# %% [raw]
# Conclusao: pp_11 --> KNN.    pp_9 --> Trees
