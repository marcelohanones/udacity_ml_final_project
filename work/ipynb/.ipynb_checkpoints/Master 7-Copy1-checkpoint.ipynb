# %% [markdown]
# # Load Data / Libs

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# %run ../modules/library_to_import.ipynb

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)  
warnings.filterwarnings("ignore", category=UserWarning)  

# np.set_printoptions(precision=2)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns
# sns.despine()
sns.set()
# sns.set(style='white', context='notebook', palette='deep')
# sns.set(style='white', palette='deep')
sns.despine()

# %% [markdown]
# # X  y

# %%
random_state = 42
kfold = StratifiedKFold(n_splits=5, shuffle=False, random_state=random_state)

# %%
# df = pd.read_csv('../../data/movie_data.csv')
data_raw = pd.read_csv("../../data/labeledTrainData.tsv", header=0, \
                    delimiter="\t", quoting=3)

# %%
data_raw.head()
data_raw.info()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 3 columns):
# id           25000 non-null object
# sentiment    25000 non-null int64
# review       25000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 586.0+ KB

# %%
data_raw.sentiment.value_counts(normalize=True)
# Out:
# 1    0.5
# 0    0.5
# Name: sentiment, dtype: float64

# %%
train_raw = data_raw[:20000]
test_raw = data_raw[20000:]

# %%
train_raw.head()
train_raw.info()
# Out:
#          id  sentiment                                             review
# 0  "5814_8"          1  "With all this stuff going down at the moment ...
# 1  "2381_9"          1  "\"The Classic War of the Worlds\" by Timothy ...
# 2  "7759_3"          0  "The film starts with a manager (Nicholas Bell...
# 3  "3630_4"          0  "It must be assumed that those who praised thi...
# 4  "9495_8"          1  "Superbly trashy and wondrously unpretentious ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 3 columns):
# id           20000 non-null object
# sentiment    20000 non-null int64
# review       20000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 468.8+ KB

# %%
test_raw.head()
test_raw.info()
# Out:
#               id  sentiment                                             review
# 20000   "3862_4"          0  "I just watched it. A couple of laughs, but no...
# 20001   "674_10"          1  "While to most people watching the movie, this...
# 20002  "8828_10"          1  "I was so glad I came across this short film. ...
# 20003   "2963_8"          1  "The creators of south park in their own film ...
# 20004   "2483_1"          0  "Unspeakably discombobulated turkey, a mix of ...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 20000 to 24999
# Data columns (total 3 columns):
# id           5000 non-null object
# sentiment    5000 non-null int64
# review       5000 non-null object
# dtypes: int64(1), object(2)
# memory usage: 117.3+ KB

# %%
X = train_raw[['review']]
y = train_raw[['sentiment']]

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=random_state)

# %%
X_train.shape
X_train.head()
y_train.shape 
y_train.head()
# Out:
# (15000, 1)
#                                                   review
# 5514   "There is a DVD published in the UK in 2002 Co...
# 1266   "Frownland is like one of those intensely emba...
# 5864   "I rented this because I'm a bit weary of '80s...
# 15865  "I like bad movies. I like to rent bad movies ...
# 12892  "The story line was very straight forward and ...
# (15000, 1)
#        sentiment
# 5514           0
# 1266           1
# 5864           0
# 15865          0
# 12892          0

# %%
X_val.shape 
X_val.head()
y_val.shape
y_val.head()
# Out:
# (5000, 1)
#                                                   review
# 10650  "I can't believe that Steven Segal's career ha...
# 2041   "I wasn't quite sure if this was just going to...
# 8668   "First of all, if you'r a fan of the comic, we...
# 1114   "I really liked this movie, and went back to s...
# 13902  "Yes, CHUNKY, this is the nick-name that Donna...
# (5000, 1)
#        sentiment
# 10650          0
# 2041           1
# 8668           0
# 1114           1
# 13902          0

# %%
test_raw.head()
# Out:
#               id  sentiment                                             review
# 20000   "3862_4"          0  "I just watched it. A couple of laughs, but no...
# 20001   "674_10"          1  "While to most people watching the movie, this...
# 20002  "8828_10"          1  "I was so glad I came across this short film. ...
# 20003   "2963_8"          1  "The creators of south park in their own film ...
# 20004   "2483_1"          0  "Unspeakably discombobulated turkey, a mix of ...

# %%
X_test = test_raw[['review']]
y_test = test_raw[['sentiment']]

# %%
X_test.shape
y_test.shape
# Out:
# (5000, 1)
# (5000, 1)

# %% [markdown]
# # PRE LOADING

# %% [markdown]
# ## Functions, instances

# %%
def tokenizer_split(text):
    return [porter.stem(w) for w in text.split(' ')]

def tokenizer_porter(text):
    return [porter.stem(w) for w in text.split(' ') if not w in stop_words ]

tfidf = TfidfVectorizer(strip_accents=None, lowercase=False, preprocessor=None)

# %%
stop_words = nltk.corpus.stopwords.words('english')
porter = PorterStemmer()

# %%
# %run ../modules/Class_imdb.ipynb
# %run ../modules/transformers_imdb.ipynb

# %%
# %run ../modules/params_imdb.ipynb

# %%
master = Super_Analytica()

# %% [markdown]
# # Load Pickle _1

# %% [raw]
# Todos os modelos processados nos notebooks anteriores serão analisados agora quanto ao score, qualidade do score (confusion matrix) e o tempo gasto para realizar toda a operação de fit e predict. Embora em cada algoritmo os tempos de fit possam ser diferentes do tempo de predict, ambos tempos foram considerados como uma única variável. No momento em que o modelo entrar em produção certamente a diferença desses tempos sera um fator decisivo. Para esta análise a intenção foi medir o tempo total que um modelo requer para ser analisado.

# %%
# checando se o repositorio de analises esta vazio.
master.get_members_evaluations_all()
# Out:
# dict_keys([])

# %% [raw]
# Os modelos serão carregados mantendo seus grupamentos de origem. Com estes "agregadores" podemos comparar a evolução dos scores de maneiras diferentes.

# %%
# Agrupando por Pipeline de origem
md_pp2 = ['DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2'] # modelos processados pelo pipeline 2
md_pp3 = ['DT_pp3', 'ADA_pp3', 'RF_pp3', 'XT_pp3', 'KNN_pp3'] # modelos processados pelo pipeline 3
md_pp4 = ['LSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4'] # modelos processados pelo pipeline 4
md_pp5 = ['LSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5'] # modelos processados pelo pipeline 5
md_HP_cv = ['KNN_HP_cv_1', 'RF_HP_cv_1', 'XT_HP_cv_1', 'LGR_HP_cv_1', 'NB_HP_cv_1', 'SGDC_HP_cv_1']  # modelos processados pela funcao HP_cv
md_PF = ['RF_PF_1', 'XT_PF_1', 'KNN_PF_1', 'LGR_PF_1', 'NB_PF_1', 'SGDC_PF_1'] # modelos processados pela funcao PARFIT
md_LGBM = ['LGBM_1']
md_HP_val = ['RF_HP_val', 'XT_HP_val', 'LGR_HP_val_1', 'LGR_HP_val', 'NB_HP_val', 'SGDC_HP_val', 'KNN_HP_val'] # modelos processados pela funcao HP_val

# %%
# Agrupando em: Parametricos e Nao Parametricos
md_Par = md_pp4 + md_pp5 + ['LGR_HP_cv_1', 'NB_HP_cv_1', 'SGDC_HP_cv_1'] + [ 'LGR_PF_1', 'NB_PF_1', 'SGDC_PF_1'] + ['LGR_HP_val', 'SGDC_HP_val', 'NB_HP_val'] 

md_NPar = md_pp2 + md_pp3 + ['KNN_HP_cv_1', 'RF_HP_cv_1', 'XT_HP_cv_1'] + ['RF_PF_1', 'XT_PF_1', 'KNN_PF_1'] + \
['KNN_HP_val', 'RF_HP_val', 'XT_HP_val'] + md_LGBM

# %%
md_all = [md_Par + md_NPar]

# %%
# models_to_load = md_all
# models_to_load = md_all      
models_to_load = md_all

# %%
for L in models_to_load:  # models_to_load must be a list of lists
    for name in L:
        master.pkl_R(name)
# Out:
# Done. LSVC_pp4 evaluation pickled from pisk
# Done. LGR_pp4 evaluation pickled from pisk
# Done. RDG_pp4 evaluation pickled from pisk
# Done. NB_pp4 evaluation pickled from pisk
# Done. SGDC_pp4 evaluation pickled from pisk
# Done. LSVC_pp5 evaluation pickled from pisk
# Done. LGR_pp5 evaluation pickled from pisk
# Done. RDG_pp5 evaluation pickled from pisk
# Done. NB_pp5 evaluation pickled from pisk
# Done. SGDC_pp5 evaluation pickled from pisk
# Done. LGR_HP_cv_1 evaluation pickled from pisk
# Done. NB_HP_cv_1 evaluation pickled from pisk
# Done. SGDC_HP_cv_1 evaluation pickled from pisk
# Done. LGR_PF_1 evaluation pickled from pisk
# Done. NB_PF_1 evaluation pickled from pisk
# Done. SGDC_PF_1 evaluation pickled from pisk
# Done. LGR_HP_val evaluation pickled from pisk
# Done. SGDC_HP_val evaluation pickled from pisk
# Done. NB_HP_val evaluation pickled from pisk
# Done. DT_pp2 evaluation pickled from pisk
# Done. ADA_pp2 evaluation pickled from pisk
# ...

# %%
# confirmando que o repositorio de analises não esta vazio.
master.get_members_evaluations_all()
# Out:
# dict_keys(['LSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4', 'LSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5', 'LGR_HP_cv_1', 'NB_HP_cv_1', 'SGDC_HP_cv_1', 'LGR_PF_1', 'NB_PF_1', 'SGDC_PF_1', 'LGR_HP_val', 'SGDC_HP_val', 'NB_HP_val', 'DT_pp2', 'ADA_pp2', 'RF_pp2', 'XT_pp2', 'KNN_pp2', 'DT_pp3', 'ADA_pp3', 'RF_pp3', 'XT_pp3', 'KNN_pp3', 'KNN_HP_cv_1', 'RF_HP_cv_1', 'XT_HP_cv_1', 'RF_PF_1', 'XT_PF_1', 'KNN_PF_1', 'KNN_HP_val', 'RF_HP_val', 'XT_HP_val', 'LGBM_1'])

# %% [markdown]
# # Score Geral

# %%
# score de todos os modelos
master.plot_ranking()

# %%
# score dos 20 melhores 
master.plot_ranking(top_n=20)

# %%
# score dos modelos Nao-Parametricos
master.plot_ranking(md_NPar)

# %%
# score dos modelos Parametricos
master.plot_ranking(md_Par)

# %% [markdown]
# # Analisando a learning_Curve dos top 4 de cada grupo

# %%
master.plot_learning_curve(chosen=['XT_PF_1', 'XT_HP_cv_1', 'XT_HP_val', 'RF_HP_cv_1'])
# Out:
# opening the image RF_HP_cv_1
# opening the image XT_HP_cv_1
# opening the image XT_HP_val
# opening the image XT_PF_1

# %%
master.plot_learning_curve(chosen=['LGR_PF_1','LGR_HP_cv_1', 'SGDC_PF_1', 'LGR_HP_val'])
# Out:
# opening the image LGR_HP_cv_1
# opening the image LGR_HP_val
# opening the image LGR_PF_1
# opening the image SGDC_PF_1

# %% [markdown]
# # Scores x Tempo

# %% [markdown]
# ## Parametricos

# %% [raw]
# Analisando o desempenho dos modelos Parametricos

# %%
print(md_Par)
# Out:
# ['LSVC_pp4', 'LGR_pp4', 'RDG_pp4', 'NB_pp4', 'SGDC_pp4', 'LSVC_pp5', 'LGR_pp5', 'RDG_pp5', 'NB_pp5', 'SGDC_pp5', 'LGR_HP_cv_1', 'NB_HP_cv_1', 'SGDC_HP_cv_1', 'LGR_PF_1', 'NB_PF_1', 'SGDC_PF_1', 'LGR_HP_val', 'SGDC_HP_val', 'NB_HP_val']

# %%
master.plot_ranking(chosen=md_Par)

# %%
master.plot_ranking(chosen=md_Par, var='minutes')

# %% [raw]
# Conclusão: De forma geral houve evolução no score dos modelos parametricos. Já o tempo gasto foi bastente variado deixando claro que as implementacoes podem  ter tempos bastante diferentes.

# %% [markdown]
# ### LGR

# %% [raw]
# Analisando os modelos de Logistic Regression

# %%
md_LGR = find_models('LGR') # produce a list of strings of models starting with 'LGR'
md_LGR
# Out:
# ['LGR_pp4', 'LGR_pp5', 'LGR_HP_cv_1', 'LGR_PF_1', 'LGR_HP_val']

# %%
master.plot_ranking(chosen=md_LGR)

# %%
master.plot_ranking(chosen=md_LGR, var='minutes')

# %% [raw]
# Conclusão: Embora todos os scores obtidos sejam parecidos, a variação do tempo gasto é enorme. Os melhores scores obteveram bons tempos.

# %% [markdown]
# --------------------------------

# %%
md_LGR
# Out:
# ['LGR_pp4', 'LGR_pp5', 'LGR_HP_cv_1', 'LGR_PF_1', 'LGR_HP_val']

# %%
master.plot_learning_curve(chosen=['LGR_pp4'])
# Out:
# opening the image LGR_pp4

# %%
master.plot_learning_curve(chosen=['LGR_HP_cv_1'])
# Out:
# opening the image LGR_HP_cv_1

# %%
master.plot_learning_curve(chosen=['LGR_PF_1'])
# Out:
# opening the image LGR_PF_1

# %%
master.plot_learning_curve(chosen=['LGR_HP_val'])
# Out:
# opening the image LGR_HP_val

# %% [raw]
# Conclusão: Embora o modelo LGR_HP_val_vect_1 tenha obtido melhor score, sua curva é caracteristica de um estado de overfitting. Já o modelo LGR_pp4 teve um score menor porem sua curva mostra um inicio de convergencia e por isso é um resultado mais robusto.

# %% [markdown]
# ---------------------------

# %% [markdown]
# #### Ensemble

# %%
# se a learning curve do pp4 converge pq a do vect_val nao converge tb ?

# %%
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings("ignore", category=DataConversionWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning)  
warnings.filterwarnings("ignore", category=UserWarning)

# %%
master.evaluations_all['LGR_pp4'].keys()

# %%
# master.evaluations_all['LGR_pp4']['best_estimator'].steps
best_mdl = master.evaluations_all['LGR_pp4']['best_estimator'].named_steps['LGR']
best_mdl
best_mdl_2 = master.evaluations_all['LGR_HP_val_vect_1']['best_estimator']
best_mdl_2

# %%
pipe_4 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(stop_words='english'))
])

best_params = {
    'vec__max_df': 0.9,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3),
    'vec__sublinear_tf': True
}

pipe_4_vect =  clone(pipe_4).set_params(**best_params)

# %%
clf['SGDC_HP_val_vect_1_BAGG'] = BaggingClassifier(base_estimator=best_mdl, n_estimators=30)

# %%
master.evaluate_CV(pipe_4_vect, ['SGDC_HP_val_vect_1_BAGG'], vectorize_first=True )

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG'], load_saved=False)

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG'], load_saved=True)

# %% [markdown]
# ----------------

# %%
# best_mdl_2
clf['SGDC_HP_val_vect_1_BAGG_2'] = BaggingClassifier(base_estimator=best_mdl_2, n_estimators=30)

# %%
master.evaluate_CV(pipe_4_vect, ['SGDC_HP_val_vect_1_BAGG_2'], vectorize_first=True )

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG_2'], load_saved=False)

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG_2'], load_saved=True)

# %% [markdown]
# ---------------

# %%
# best_mdl com truncated pra reduzir overfitting

# %%
pipe_5 = Pipeline([
    ('col', Col_Extractor(['review'])),
    ('prep', Preprocessor()),
    ('to_array', To_array()),
    ('vec', TfidfVectorizer(stop_words='english')),
    ('svd', TruncatedSVD(n_components=500))
])

best_params = {
    'vec__max_df': 0.9,
    'vec__min_df': 2,
    'vec__ngram_range': (1, 3),
    'vec__sublinear_tf': True
}

pipe_5_vect =  clone(pipe_4).set_params(**best_params)

# %%
clf['SGDC_HP_val_vect_1_BAGG_3'] = BaggingClassifier(base_estimator=best_mdl, n_estimators=50)

# %%
master.evaluate_CV(pipe_5_vect, ['SGDC_HP_val_vect_1_BAGG_3'], vectorize_first=True )

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG_3'], load_saved=False)

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val_vect_1_BAGG_3'], load_saved=True)

# %%
master

# %% [markdown]
# ### NB

# %%
md_NB = find_models('NB')
master.plot_ranking(chosen=md_NB)

# %%
master.plot_ranking(chosen=md_NB, var='minutes')

# %% [raw]
# Conclusão: Entre os modelos tunados nao houve muita diferenca de score, todos performaram em 0.94. Porém os tempos variaram bastante.

# %% [markdown]
# -----------------------

# %%
master.plot_learning_curve(chosen=['NB_HP_cv_1'])
# Out:
# opening the image NB_HP_cv_1

# %%
master.plot_learning_curve(chosen=['NB_HP_val'])
# Out:
# opening the image NB_HP_val

# %% [raw]
# Conclusão: A curva mostra convergencia entre os scores.

# %% [markdown]
# ### SGDC

# %%
md_SGDC = find_models('SGDC')
master.plot_ranking(chosen=md_SGDC)

# %%
master.plot_ranking(chosen=md_SGDC, var='minutes')

# %% [raw]
# Conclusão: Houve pequena evolução no score dos modelos comparando com outros modelos. No tempo gasto a melhora foi bem grande. Neste caso houve o cenário perfeito, onde o score melhorou e o tempo diminuiu.

# %% [markdown]
# -------------------------

# %%
md_SGDC
# Out:
# ['SGDC_pp4', 'SGDC_pp5', 'SGDC_HP_cv_1', 'SGDC_PF_1', 'SGDC_HP_val']

# %%
master.plot_learning_curve(chosen=['SGDC_pp4'])
# Out:
# opening the image SGDC_pp4

# %%
master.plot_learning_curve(chosen=['SGDC_HP_cv_1'])
# Out:
# opening the image SGDC_HP_cv_1

# %%
master.plot_learning_curve(chosen=['SGDC_PF_1'])
# Out:
# opening the image SGDC_PF_1

# %%
master.plot_learning_curve(chosen=['SGDC_HP_val'])
# Out:
# opening the image SGDC_HP_val

# %% [raw]
# Conclusão:

# %% [markdown]
# ## Não paramétricos

# %% [raw]
# KNN, RF e XT, LGBM

# %% [markdown]
# ### KNN

# %%
md_KNN = find_models('KNN') # produce a list of strings of the models that starts with 'LGR'
md_KNN
# Out:
# ['KNN_pp2', 'KNN_pp3', 'KNN_HP_cv_1', 'KNN_PF_1', 'KNN_HP_val']

# %%
master.plot_ranking(chosen=md_KNN)

# %%
master.plot_ranking(chosen=md_KNN, var='minutes')

# %% [raw]
# Conclusão: A evolução dos scores dos modelos tunados nao é grande. Os melhores scores obteveram os melhores tempos, porém o segundo, terceiro lugares tiveram o mesmo score mas tempos bastante diferentes.

# %% [markdown]
# ------------------------

# %%
# Analisando a learning curve dos dois melhores scores

# %%
master.plot_learning_curve(chosen=['KNN_HP_val'])
# Out:
# opening the image KNN_HP_val

# %%
master.plot_learning_curve(chosen=['KNN_HP_val'])
# Out:
# opening the image KNN_HP_val

# %% [raw]
# Conclusão: Ambas curvas sao semelhantes e mostram que o modelo nao sofre de overfitting. O modelo parece ter entrado em convergencia, portanto atingido seu limite.

# %% [raw]
# Conclusão

# %% [markdown]
# ### RF

# %%
md_RF = find_models('RF')
master.plot_ranking(chosen=md_RF)

# %%
master.plot_ranking(chosen=md_RF, var='minutes')

# %% [raw]
# Conclusão: os melhores scores foram os mais demorados. Se o tempo gasto for uma variável importante a se considerar, os melhores scores podem nao ser as melhores alternativas.

# %% [markdown]
# ---------------------------

# %%
master.plot_learning_curve(chosen=['RF_HP_val'])
# Out:
# opening the image RF_HP_val

# %%
master.plot_learning_curve(chosen=['RF_HP_cv_1'])
# Out:
# opening the image RF_HP_cv_1

# %% [raw]
# Conclusão: Ambos modelos mostram uma curva em completo overfitting.

# %% [markdown]
# ------------------------

# %% [markdown]
# ### XT

# %%
md_XT = find_models('XT')
master.plot_ranking(chosen=md_XT)

# %%
master.plot_ranking(chosen=md_XT, var='minutes')

# %% [raw]
# Conclusão: Houve pouca evolução no score dos modelos, todos performaram em 0.92. O tempo gasto foi variado. Neste caso houve o cenário perfeito, onde o melhor score obteve o melhor tempo.

# %% [markdown]
# ---------------------

# %%
master.plot_learning_curve(chosen=['XT_PF_1'])
# Out:
# opening the image XT_PF_1

# %%
master.plot_learning_curve(chosen=['XT_HP_cv_1'])
# Out:
# opening the image XT_HP_cv_1

# %% [raw]
# Conclusão: Ambos modelos mostram uma curva em completo overfitting.

# %%
master.plot_Confusion_Matrix(chosen=['XT_PF_1'])
# Out:
# opening the image XT_PF_1

# %%
master.plot_Confusion_Matrix(chosen=['XT_HP_cv_1'])
# Out:
# opening the image XT_HP_cv_1

# %% [markdown]
# ## LGBM

# %% [raw]
# Como ultimo modelo analisado, optei por incluir uma biblioteca de boosting que tem obtido bastante destaque recentemente, LightGBM.

# %%
md_LGBM

# %%
md_LGBM = find_models('LGBM')
master.plot_ranking(chosen=md_LGBM)

# %%
master.plot_ranking(chosen=md_LGBM, var='minutes')

# %%
master.plot_learning_curve(chosen=['LGBM_1'])
# Out:
# opening the image LGBM_1

# %%
master.plot_Confusion_Matrix(chosen=['LGBM_1'])
# Out:
# opening the image LGBM_1

# %% [raw]
# Conclusão:
